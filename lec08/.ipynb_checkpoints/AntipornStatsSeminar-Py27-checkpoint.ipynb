# %% [markdown]
# # ** Описание **

# %% [raw]
# Ссылка на соревнование:
# https://kaggle.com/join/antoporn_bayes
# Ссылка на данные:
# https://inclass.kaggle.com/c/antiporn-infopoisk/data
#
# Нужно набрать больше 0.89, чтобы получить +1 балл к следующему ДЗ
# и 0.9, чтобы получить +2 балла

# %% [markdown]
# $$P(AB)=P(A|B)P(B)=P(B|A)P(A)$$
# $$P(A|B)=\frac{P(B|A)P(A)}{P(B)}$$
# $$P(C|D)=\frac{P(D|C)P(C)}{P(D)}=\frac{P(x_1..x_n|C)P(C)}{P(D)}$$
# Наивность заключается в том, что мы считаем все слова(признаки) независимыми между собой
# $$P(x_1..x_n|C)=\prod_{i}^{n}P(x_i|C)$$

# %% [markdown]
# Соответственно тогда, вероятности того, что документ принадлежит каждому классу можно записат следующим образом

# %% [markdown]
# $$P(C|D)=\frac{\prod_{i}^{n}P(x_i|C)P(C)}{P(D)}$$
# $$P(\neg C|D)=\frac{\prod_{i}^{n}P(x_i|\neg C)P(\neg C)}{P(D)}$$

# %% [markdown]
# Если поделить две эти вероятности, то мы сократим общие члены и упростим формулу

# %% [markdown]
# $$\frac{P(C|D)}{P(\neg C|D)}=\frac{\prod_{i}^{n}P(x_i|C)P(C)}{\prod_{i}^{n}P(x_i|\neg C)P(\neg C)}$$
# $$ln\frac{P(C|D)}{P(\neg C|D)}=ln\frac{P(C)}{P(\neg C)}+\sum_{i}^{n}ln\frac{P(x_i|C)}{P(x_i|\neg C)}=$$
# $$ln\frac{P(C)}{P(\neg C)}+\sum_{i}^{n}ln\frac{classCfreqX_i}{classNotCfreqX_i}$$
# $$P(x_i|C)=classCfreqX_i/total$$
# $$P(x_i|\neg C)=classNotCfreqX_i/total$$
# $$ln\frac{P(C)}{P(\neg C)} = const$$
# $$P(C|D) + P(\neg C|D) = 1$$

# %%
from __future__ import division

import base64
import csv
import gzip
from math import log
import zlib
import random
import numpy

from collections import namedtuple
from collections import Counter

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
TRACE_NUM = 500
import logging
reload(logging)
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.INFO, datefmt='%H:%M:%S')

def trace(items_num, trace_num=TRACE_NUM):
    if items_num % trace_num == 0: logging.info("Complete items %05d" % items_num)

# %% [markdown]
# ### Утилиты

# %% [markdown]
# #### Декораторы

# %%
def to_utf8(text):
    if isinstance(text, unicode): text = text.encode('utf8')
    return text

def convert2unicode(f):
    def tmp(text):
        if not isinstance(text, unicode): text = text.decode('utf8')
        return f(text)
    return tmp

def convert2lower(f):
    def tmp(text):        
        return f(text.lower())
    return tmp

#P.S. Декораторы могут усложнять отладку, так что от них вполне можно отказаться и воспользоваться copy-paste

# %% [markdown]
# ### Извлечение текста из html

# %% [markdown]
# #### Извлечение текста при помощи встроенных модулей

# %%
from HTMLParser import HTMLParser
import re

###Извлечение текста из title можно вписать сюда

class TextHTMLParser(HTMLParser):
    def __init__(self):
        HTMLParser.__init__(self)
        self._text = []
        self._title = ""
        self._in_title = False

    def handle_data(self, data):
        text = data.strip()
        if len(text) > 0:
            text = re.sub('[ \t\r\n]+', ' ', text)
            self._text.append(text + ' ')

    def handle_starttag(self, tag, attrs):
        if tag == 'p':
            self._text.append('\n\n')
        elif tag == 'br':
            self._text.append('\n')
        elif tag == 'title':
            self._in_title = True

    def handle_startendtag(self, tag, attrs):
        if tag == 'br':
            self._text.append('\n\n')

    def text(self):
        return ''.join(self._text).strip()

@convert2unicode
def html2text_parser(text):
    parser = TextHTMLParser()
    parser.feed(text)
    return parser.text()

# %% [markdown]
# #### Извлечение текста при помощи дополнительных библиотек

# %%
def html2text_bs(raw_html):
    from bs4 import BeautifulSoup
    """
    Тут производится извлечения из html текста
    """
    soup = BeautifulSoup(raw_html, "html.parser")
    [s.extract() for s in soup(['script', 'style'])]
    return soup.get_text()

def html2text_bs_visible(raw_html):
    from bs4 import BeautifulSoup
    """
    Тут производится извлечения из html текста, который видим пользователю
    """
    soup = BeautifulSoup(raw_html, "html.parser")    
    [s.extract() for s in soup(['style', 'script', '[document]', 'head', 'title'])]
    return soup.get_text()

def html2text_boilerpipe(raw_html):
    import boilerpipe
    """
    еще одна библиотека очень хорошо извлекающая именно видимый пользователю текст,
    но она завязана на java
    """
    pass

# %% [markdown]
# #### Выбираем какой метод для конвертации html в текст будет основным

# %%
#html2text = html2text_bs
html2text = html2text_parser

# %% [markdown]
# #### Методы для токенизации текста

# %%
@convert2lower
@convert2unicode
def easy_tokenizer(text):
    word = unicode()
    for symbol in text:
        if symbol.isalnum(): word += symbol
        elif word:
            yield word
            word = unicode()
    if word: yield word

PYMORPHY_CACHE = {}
MORPH = None
#hint, чтобы установка pymorphy2 не была бы обязательной
def get_lemmatizer():
    import pymorphy2
    global MORPH
    if MORPH is None: MORPH = pymorphy2.MorphAnalyzer()
    return MORPH

@convert2lower
@convert2unicode
def pymorphy_tokenizer(text):
    global PYMORPHY_CACHE
    for word in easy_tokenizer(text):
        word_hash = hash(word)
        if word_hash not in PYMORPHY_CACHE:
            PYMORPHY_CACHE[word_hash] = get_lemmatizer().parse(word)[0].normal_form            
        yield PYMORPHY_CACHE[word_hash]

# %% [markdown]
# #### Основная функция, которая вызывается для преобразования html в список слов

# %%
def html2word(raw_html, to_text=html2text, tokenizer=easy_tokenizer):
    return tokenizer(to_text(raw_html).lower())

# %% [markdown]
# #### Рассчет финальных метрик

# %%
def safe_divide(a, b):
    if a == 0: return 0.0
    elif b == 0: return 0.0
    else: return a/b

def calculate_metrics(predictions, threshold):    
    """
    Функция подсчета метрик
    Параметры
    predictions - ранки по документам
    threshold  - порог для метрик
    """
    true_positive = 0
    false_positive = 0
    true_negative = 0
    false_negative = 0
    for (url_id, mark, url, prediction) in predictions:        
        mark_predict = prediction > threshold

        if mark_predict:                     
            if mark_predict == mark: true_positive += 1
            else: false_positive += 1                    
        else:                     
            if  mark_predict == mark: true_negative += 1
            else: false_negative += 1

    class_prec  = safe_divide(true_positive, true_positive + false_positive)
    class_recall = safe_divide(true_positive, true_positive + false_negative)
        
    class_F1 = safe_divide(2 * class_prec * class_recall, class_prec + class_recall)
    
    
    not_class_prec = safe_divide(true_negative, true_negative + false_negative)
    not_class_recall = safe_divide(true_negative, true_negative + false_positive)
    
    not_class_F1 = safe_divide(2 * not_class_prec * not_class_recall, not_class_prec + not_class_recall)
    
    return ( (class_prec, class_recall, class_F1), (not_class_prec, not_class_recall, not_class_F1) )

def arange(start, stop, step):
    cur_value = start
    while True:
        if cur_value > stop: break
        yield cur_value
        cur_value += step

def plot_results(docs, min_threshold=-1, max_threshold=1, step=0.1, trace=False):
    x = []
    y_p = []
    y_n = []
    docs_predictions = classifier.predict_all(docs)
    for threshold in arange(min_threshold, max_threshold, step):
        r = calculate_metrics(docs_predictions, threshold)
        x.append(threshold)
        y_p.append(r[0])
        y_n.append(r[1])        
        if trace: 
            print 'threshold %s' % threshold
            print '\tclass_prec %s, class_recall %s, class_F1 %s' % r[0]
            print '\tnot_class_prec %s, not_class_recall %s, not_class_F1 %s' % r[1]
            print '\t\tMacroF1Mesure %s' % ((r[0][2] + r[1][2])/2)
    plot_stats(x, y_p, "Class Result")
    plot_stats(x, y_n, "Not class Result")    


def plot_stats(x, y, title):
    plt.figure(figsize=(10, 5))

    prec, = plt.plot( x, 
                     [k[0] for k in y], "r", label='Precision', 
                     linewidth=1)
    accur, = plt.plot( x, 
                      [k[1] for k in y], "b", label='Recall',
                      linewidth=1)
    f1, =    plt.plot( x, 
                      [k[2] for k in y], "g", label='F1',
                      linewidth=1)
    plt.grid(True)
    plt.legend(handles=[prec, accur, f1])
    plt.title(title)
    plt.show()

# %%
test_html_data = u'''
<html>
<title> Заголовок Ololo </title>
спам 1 2 3
</html>
'''
test_url = 'http://ololo'
test_words = list(html2word(test_html_data))
for word in test_words:
    print word
# Out:
# заголовок
# ololo
# спам
# 1
# 2
# 3

# %%
DocItem = namedtuple('DocItem', ['doc_id', 'is_class', 'url', 'words'])

def load_csv(input_file_name):    
    """
    Загружаем данные и извлекаем на лету слова
    Сам контент не сохраняется, чтобы уменьшить потребление памяти - чтобы
    можно было запускать даже на ноутбуках в классе
    """
    
    with gzip.open(input_file_name) if input_file_name.endswith('gz') else open(input_file_name)  as input_file:            
        headers = input_file.readline()
        
        for i, line in enumerate(input_file):
            trace(i)
            parts = line.strip().split('\t')
            url_id = int(parts[0])                                        
            mark = bool(int(parts[1]))                    
            url = parts[2]
            pageInb64 = parts[3]
            html_data = base64.b64decode(pageInb64)
            words = list(html2word(html_data))
            yield DocItem(url_id, mark, url, words)            
                
        trace(i, 1)

# %% [markdown]
# ** Обрабатываем входной файл **
# <br>
# Формат - поля разделенные табуляциями
# <br>
# 0 - идентификатор документа
# <br>
# 1 - метка класса 0 - не порно, 1 - порно
# <br>
# 2 - урл документа
# <br>
# 3 - документ в кодировке base64
#
# Выходной формат - массив кортежей вида
# (doc_id, is_class, url, html_data)

# %%
TRAIN_DATA_FILE  = 'kaggle_train_data_tab.csv.gz'
train_docs = list(load_csv(TRAIN_DATA_FILE))
# Out:
# 17:21:39 INFO:Complete items 00000
# 17:21:54 INFO:Complete items 00500
# 17:22:05 INFO:Complete items 01000
# 17:22:15 INFO:Complete items 01500
# 17:22:24 INFO:Complete items 02000
# 17:22:32 INFO:Complete items 02500
# 17:22:39 INFO:Complete items 03000
# 17:22:40 INFO:Complete items 03138

# %% [markdown]
# ** Классификатор: **
# Нужно реализовать

# %%
train_docs[0].doc_id
# Out:
# -9221781266852579122

# %%
class Classifier:
    
    def __init__(self):
        self.counters = []
        self.counters.append(Counter())
        self.counters.append(Counter())
    
    def predict_porno(self, doc):        
        return u'порно' in doc.words
    
    def predict_random(self, doc):
        #Чтобы для каждого документа рандом был детерминирован
        random.seed(doc.doc_id)
        return random.random()

    def predict(self, doc):
        pred = 0
        words_used = 0
        for word in doc.words:
            if self.counters[True][word] == 0:
                continue
            words_used += 1
            pred += log(self.counters[True][word] / (self.counters[False][word] + 1))
        return pred / words_used
    
    def predict_all(self, docs):
        res = []
        for doc_num, doc in enumerate(docs):
            trace(doc_num)
            prediction = self.predict(doc)            
            res.append( (doc.doc_id, doc.is_class, doc.url, prediction) )
        return res
    
    def train(self, docs):                
        for doc_num, doc in enumerate(docs):                            
            for word in doc.words:
                self.counters[doc.is_class][word] += 1
            trace(doc_num)
        trace(doc_num, 1)

# %%
classifier = Classifier()
classifier.train(train_docs)
# Out:
# 18:01:59 INFO:Complete items 00000
# 18:02:00 INFO:Complete items 00500
# 18:02:02 INFO:Complete items 01000
# 18:02:02 INFO:Complete items 01500
# 18:02:03 INFO:Complete items 02000
# 18:02:04 INFO:Complete items 02500
# 18:02:05 INFO:Complete items 03000
# 18:02:06 INFO:Complete items 03138

# %%
#Посмотреть, что предсказывается для тестового html
classifier.predict(DocItem(0, 0, test_url , test_words))
# Out:
# -0.6148217232380965

# %% [markdown]
# ** Рисуем графики **

# %%
plot_results(train_docs, min_threshold=-0.9, max_threshold=-0.7, step=0.001, trace=1)
# Out:
# 18:02:06 INFO:Complete items 00000
# 18:02:08 INFO:Complete items 00500
# 18:02:09 INFO:Complete items 01000
# 18:02:11 INFO:Complete items 01500
# 18:02:12 INFO:Complete items 02000
# 18:02:14 INFO:Complete items 02500
# 18:02:15 INFO:Complete items 03000
# threshold -0.9
# 	class_prec 0.877902621723, class_recall 0.956734693878, class_F1 0.915625
# 	not_class_prec 0.970620842572, not_class_recall 0.914838035528, not_class_F1 0.941904249597
# 		MacroF1Mesure 0.928764624798
# threshold -0.899
# 	class_prec 0.87856071964, class_recall 0.956734693878, class_F1 0.915982805784
# 	not_class_prec 0.970637119114, not_class_recall 0.915360501567, not_class_F1 0.942188760419
# 		MacroF1Mesure 0.929085783101
# threshold -0.898
# 	class_prec 0.879219804951, class_recall 0.956734693878, class_F1 0.916340891321
# 	not_class_prec 0.97065337763, not_class_recall 0.915882967607, not_class_F1 0.94247311828
# 		MacroF1Mesure 0.9294070048
# threshold -0.897
# 	class_prec 0.87969924812, class_recall 0.955102040816, class_F1 0.915851272016
# 	not_class_prec 0.969596462134, not_class_recall 0.916405433647, not_class_F1 0.942250872952
# 		MacroF1Mesure 0.929051072484
# threshold -0.896
# 	class_prec 0.87969924812, class_recall 0.955102040816, class_F1 0.915851272016
# 	not_class_prec 0.969596462134, not_class_recall 0.916405433647, not_class_F1 0.942250872952
# 		MacroF1Mesure 0.929051072484
# threshold -0.895
# 	class_prec 0.87969924812, class_recall 0.955102040816, class_F1 0.915851272016
# 	not_class_prec 0.969596462134, not_class_recall 0.916405433647, not_class_F1 0.942250872952
# 		MacroF1Mesure 0.929051072484
# threshold -0.894
# 	class_prec 0.880271084337, class_recall 0.954285714286, class_F1 0.915785350568
# 	not_class_prec 0.969077857537, not_class_recall 0.916927899687, not_class_F1 0.942281879195
# 		MacroF1Mesure 0.929033614881
# threshold -0.893
# 	class_prec 0.880934438583, class_recall 0.954285714286, class_F1 0.916144200627
# 	not_class_prec 0.969094922737, not_class_recall 0.917450365726, not_class_F1 0.94256575416
# 		MacroF1Mesure 0.929354977393
# threshold -0.892
# 	class_prec 0.881598793363, class_recall 0.954285714286, class_F1 0.916503332027
# 	not_class_prec 0.969111969112, not_class_recall 0.917972831766, not_class_F1 0.942849476791
# 		MacroF1Mesure 0.929676404409
# threshold -0.891
# 	class_prec 0.881598793363, class_recall 0.954285714286, class_F1 0.916503332027
# 	not_class_prec 0.969111969112, not_class_recall 0.917972831766, not_class_F1 0.942849476791
# 		MacroF1Mesure 0.929676404409
# threshold -0.89
# 	class_prec 0.881598793363, class_recall 0.954285714286, class_F1 0.916503332027
# 	not_class_prec 0.969111969112, not_class_recall 0.917972831766, not_class_F1 0.942849476791
# 		MacroF1Mesure 0.929676404409
# threshold -0.889
# 	class_prec 0.881509433962, class_recall 0.953469387755, class_F1 0.916078431373
# 	not_class_prec 0.968577728776, not_class_recall 0.917972831766, not_class_F1 0.942596566524
# 		MacroF1Mesure 0.929337498948
# threshold -0.888
# 	class_prec 0.882175226586, class_recall 0.953469387755, class_F1 0.916437818752
# 	not_class_prec 0.968595041322, not_class_recall 0.918495297806, not_class_F1 0.942880128721
# 		MacroF1Mesure 0.929658973737
# threshold -0.887
# 	class_prec 0.882175226586, class_recall 0.953469387755, class_F1 0.916437818752
# 	not_class_prec 0.968595041322, not_class_recall 0.918495297806, not_class_F1 0.942880128721
# 		MacroF1Mesure 0.929658973737
# threshold -0.886
# 	class_prec 0.883421650265, class_recall 0.952653061224, class_F1 0.91673212883
# 	not_class_prec 0.968096809681, not_class_recall 0.919540229885, not_class_F1 0.943193997856
# 		MacroF1Mesure 0.929963063343
# threshold -0.885
# 	class_prec 0.8840030326, class_recall 0.951836734694, class_F1 0.916666666667
# 	not_class_prec 0.967582417582, not_class_recall 0.920062695925, not_class_F1 0.94322442421
# 		MacroF1Mesure 0.929945545438
# threshold -0.884
# 	class_prec 0.884673748103, class_recall 0.951836734694, class_F1 0.917027133307
# 	not_class_prec 0.96760021966, not_class_recall 0.920585161964, not_class_F1 0.943507362784
# 		MacroF1Mesure 0.930267248046
# threshold -0.883
# 	class_prec 0.884673748103, class_recall 0.951836734694, class_F1 0.917027133307
# 	not_class_prec 0.96760021966, not_class_recall 0.920585161964, not_class_F1 0.943507362784
# 		MacroF1Mesure 0.930267248046
# threshold -0.882
# 	class_prec 0.885345482156, class_recall 0.951836734694, class_F1 0.917387883556
# 	not_class_prec 0.967618002195, not_class_recall 0.921107628004, not_class_F1 0.943790149893
# 		MacroF1Mesure 0.930589016725
# threshold -0.881
# 	class_prec 0.885345482156, class_recall 0.951836734694, class_F1 0.917387883556
# 	not_class_prec 0.967618002195, not_class_recall 0.921107628004, not_class_F1 0.943790149893
# 		MacroF1Mesure 0.930589016725
# threshold -0.88
# 	class_prec 0.885345482156, class_recall 0.951836734694, class_F1 0.917387883556
# 	not_class_prec 0.967618002195, not_class_recall 0.921107628004, not_class_F1 0.943790149893
# 		MacroF1Mesure 0.930589016725
# threshold -0.879
# 	class_prec 0.886018237082, class_recall 0.951836734694, class_F1 0.917748917749
# 	not_class_prec 0.967635765222, not_class_recall 0.921630094044, not_class_F1 0.944072785657
# 		MacroF1Mesure 0.930910851703
# threshold -0.878
# 	class_prec 0.886692015209, class_recall 0.951836734694, class_F1 0.91811023622
# 	not_class_prec 0.967653508772, not_class_recall 0.922152560084, not_class_F1 0.944355270198
# 		MacroF1Mesure 0.931232753209
# threshold -0.877
# 	class_prec 0.886519421173, class_recall 0.950204081633, class_F1 0.917257683215
# 	not_class_prec 0.966593647317, not_class_recall 0.922152560084, not_class_F1 0.94385026738
# 		MacroF1Mesure 0.930553975297
# threshold -0.876
# 	class_prec 0.886519421173, class_recall 0.950204081633, class_F1 0.917257683215
# 	not_class_prec 0.966593647317, not_class_recall 0.922152560084, not_class_F1 0.94385026738
# 		MacroF1Mesure 0.930553975297
# threshold -0.875
# 	class_prec 0.886432926829, class_recall 0.949387755102, class_F1 0.916830902641
# 	not_class_prec 0.966064586754, not_class_recall 0.922152560084, not_class_F1 0.943597968458
# 		MacroF1Mesure 0.930214435549
# threshold -0.874
# 	class_prec 0.886432926829, class_recall 0.949387755102, class_F1 0.916830902641
# 	not_class_prec 0.966064586754, not_class_recall 0.922152560084, not_class_F1 0.943597968458
# 		MacroF1Mesure 0.930214435549
# threshold -0.873
# 	class_prec 0.886346300534, class_recall 0.948571428571, class_F1 0.916403785489
# 	not_class_prec 0.965536105033, not_class_recall 0.922152560084, not_class_F1 0.943345804383
# 		MacroF1Mesure 0.929874794936
# threshold -0.872
# 	class_prec 0.888293802601, class_recall 0.947755102041, class_F1 0.917061611374
# 	not_class_prec 0.965065502183, not_class_recall 0.923719958203, not_class_F1 0.943940202883
# 		MacroF1Mesure 0.930500907129
# threshold -0.871
# 	class_prec 0.888293802601, class_recall 0.947755102041, class_F1 0.917061611374
# 	not_class_prec 0.965065502183, not_class_recall 0.923719958203, not_class_F1 0.943940202883
# 		MacroF1Mesure 0.930500907129
# threshold -0.87
# 	class_prec 0.888293802601, class_recall 0.947755102041, class_F1 0.917061611374
# 	not_class_prec 0.965065502183, not_class_recall 0.923719958203, not_class_F1 0.943940202883
# 		MacroF1Mesure 0.930500907129
# threshold -0.869
# 	class_prec 0.888293802601, class_recall 0.947755102041, class_F1 0.917061611374
# 	not_class_prec 0.965065502183, not_class_recall 0.923719958203, not_class_F1 0.943940202883
# 		MacroF1Mesure 0.930500907129
# threshold -0.868
# 	class_prec 0.888293802601, class_recall 0.947755102041, class_F1 0.917061611374
# 	not_class_prec 0.965065502183, not_class_recall 0.923719958203, not_class_F1 0.943940202883
# 		MacroF1Mesure 0.930500907129
# threshold -0.867
# 	class_prec 0.888208269525, class_recall 0.94693877551, class_F1 0.916633741604
# 	not_class_prec 0.964539007092, not_class_recall 0.923719958203, not_class_F1 0.943688283961
# 		MacroF1Mesure 0.930161012782
# threshold -0.866
# 	class_prec 0.890253261704, class_recall 0.94693877551, class_F1 0.917721518987
# 	not_class_prec 0.964596949891, not_class_recall 0.925287356322, not_class_F1 0.944533333333
# 		MacroF1Mesure 0.93112742616
# threshold -0.865
# 	class_prec 0.890168970814, class_recall 0.94612244898, class_F1 0.917293233083
# 	not_class_prec 0.964071856287, not_class_recall 0.925287356322, not_class_F1 0.944281524927
# 		MacroF1Mesure 0.930787379005
# threshold -0.864
# 	class_prec 0.890168970814, class_recall 0.94612244898, class_F1 0.917293233083
# 	not_class_prec 0.964071856287, not_class_recall 0.925287356322, not_class_F1 0.944281524927
# 		MacroF1Mesure 0.930787379005
# threshold -0.863
# 	class_prec 0.890853189854, class_recall 0.94612244898, class_F1 0.917656373713
# 	not_class_prec 0.9640914037, not_class_recall 0.925809822362, not_class_F1 0.944562899787
# 		MacroF1Mesure 0.93110963675
# threshold -0.862
# 	class_prec 0.891454965358, class_recall 0.945306122449, class_F1 0.917591125198
# 	not_class_prec 0.963586956522, not_class_recall 0.926332288401, not_class_F1 0.944592434736
# 		MacroF1Mesure 0.931091779967
# threshold -0.861
# 	class_prec 0.892664092664, class_recall 0.943673469388, class_F1 0.91746031746
# 	not_class_prec 0.962581344902, not_class_recall 0.927377220481, not_class_F1 0.944651410325
# 		MacroF1Mesure 0.931055863892
# threshold -0.86
# 	class_prec 0.893353941267, class_recall 0.943673469388, class_F1 0.917824533545
# 	not_class_prec 0.962601626016, not_class_recall 0.92789968652, not_class_F1 0.944932162809
# 		MacroF1Mesure 0.931378348177
# threshold -0.859
# 	class_prec 0.893353941267, class_recall 0.943673469388, class_F1 0.917824533545
# 	not_class_prec 0.962601626016, not_class_recall 0.92789968652, not_class_F1 0.944932162809
# 		MacroF1Mesure 0.931378348177
# threshold -0.858
# 	class_prec 0.893353941267, class_recall 0.943673469388, class_F1 0.917824533545
# 	not_class_prec 0.962601626016, not_class_recall 0.92789968652, not_class_F1 0.944932162809
# 		MacroF1Mesure 0.931378348177
# threshold -0.857
# 	class_prec 0.897435897436, class_recall 0.942857142857, class_F1 0.919585987261
# 	not_class_prec 0.962203023758, not_class_recall 0.931034482759, not_class_F1 0.946362187998
# 		MacroF1Mesure 0.93297408763
# threshold -0.856
# 	class_prec 0.897435897436, class_recall 0.942857142857, class_F1 0.919585987261
# 	not_class_prec 0.962203023758, not_class_recall 0.931034482759, not_class_F1 0.946362187998
# 		MacroF1Mesure 0.93297408763
# threshold -0.855
# 	class_prec 0.897435897436, class_recall 0.942857142857, class_F1 0.919585987261
# 	not_class_prec 0.962203023758, not_class_recall 0.931034482759, not_class_F1 0.946362187998
# 		MacroF1Mesure 0.93297408763
# threshold -0.854
# 	class_prec 0.898133748056, class_recall 0.942857142857, class_F1 0.919952210275
# 	not_class_prec 0.962223421479, not_class_recall 0.931556948798, not_class_F1 0.946641890098
# 		MacroF1Mesure 0.933297050187
# threshold -0.853
# 	class_prec 0.898133748056, class_recall 0.942857142857, class_F1 0.919952210275
# 	not_class_prec 0.962223421479, not_class_recall 0.931556948798, not_class_F1 0.946641890098
# 		MacroF1Mesure 0.933297050187
# threshold -0.852
# 	class_prec 0.898753894081, class_recall 0.942040816327, class_F1 0.919888401754
# 	not_class_prec 0.961725067385, not_class_recall 0.932079414838, not_class_F1 0.946670204298
# 		MacroF1Mesure 0.933279303026
# threshold -0.851
# 	class_prec 0.898753894081, class_recall 0.942040816327, class_F1 0.919888401754
# 	not_class_prec 0.961725067385, not_class_recall 0.932079414838, not_class_F1 0.946670204298
# 		MacroF1Mesure 0.933279303026
# threshold -0.85
# 	class_prec 0.898674980514, class_recall 0.941224489796, class_F1 0.919457735247
# 	not_class_prec 0.961206896552, not_class_recall 0.932079414838, not_class_F1 0.946419098143
# 		MacroF1Mesure 0.932938416695
# threshold -0.849
# 	class_prec 0.899297423888, class_recall 0.940408163265, class_F1 0.919393455706
# 	not_class_prec 0.960710441335, not_class_recall 0.932601880878, not_class_F1 0.946447507953
# 		MacroF1Mesure 0.93292048183
# threshold -0.848
# 	class_prec 0.9, class_recall 0.940408163265, class_F1 0.919760479042
# 	not_class_prec 0.960731576116, not_class_recall 0.933124346917, not_class_F1 0.946726742645
# 		MacroF1Mesure 0.933243610844
# threshold -0.847
# 	class_prec 0.901408450704, class_recall 0.940408163265, class_F1 0.920495405513
# 	not_class_prec 0.960773777539, not_class_recall 0.934169278997, not_class_F1 0.947284768212
# 		MacroF1Mesure 0.933890086863
# threshold -0.846
# 	class_prec 0.901331245106, class_recall 0.939591836735, class_F1 0.920063948841
# 	not_class_prec 0.960257787325, not_class_recall 0.934169278997, not_class_F1 0.947033898305
# 		MacroF1Mesure 0.933548923573
# threshold -0.845
# 	class_prec 0.901331245106, class_recall 0.939591836735, class_F1 0.920063948841
# 	not_class_prec 0.960257787325, not_class_recall 0.934169278997, not_class_F1 0.947033898305
# 		MacroF1Mesure 0.933548923573
# threshold -0.844
# 	class_prec 0.902668759812, class_recall 0.938775510204, class_F1 0.920368147259
# 	not_class_prec 0.959785522788, not_class_recall 0.935214211076, not_class_F1 0.947340566287
# 		MacroF1Mesure 0.933854356773
# threshold -0.843
# 	class_prec 0.904088050314, class_recall 0.938775510204, class_F1 0.921105326392
# 	not_class_prec 0.959828602035, not_class_recall 0.936259143156, not_class_F1 0.947897381645
# 		MacroF1Mesure 0.934501354018
# threshold -0.842
# 	class_prec 0.905511811024, class_recall 0.938775510204, class_F1 0.921843687375
# 	not_class_prec 0.959871589085, not_class_recall 0.937304075235, not_class_F1 0.948453608247
# 		MacroF1Mesure 0.935148647811
# threshold -0.841
# 	class_prec 0.905511811024, class_recall 0.938775510204, class_F1 0.921843687375
# 	not_class_prec 0.959871589085, not_class_recall 0.937304075235, not_class_F1 0.948453608247
# 		MacroF1Mesure 0.935148647811
# threshold -0.84
# 	class_prec 0.905437352246, class_recall 0.937959183673, class_F1 0.92141138733
# 	not_class_prec 0.95935828877, not_class_recall 0.937304075235, not_class_F1 0.948202959831
# 		MacroF1Mesure 0.93480717358
# threshold -0.839
# 	class_prec 0.906151419558, class_recall 0.937959183673, class_F1 0.921780986763
# 	not_class_prec 0.959380010689, not_class_recall 0.937826541275, not_class_F1 0.948480845443
# 		MacroF1Mesure 0.935130916103
# threshold -0.838
# 	class_prec 0.907582938389, class_recall 0.937959183673, class_F1 0.922521075873
# 	not_class_prec 0.959423384944, not_class_recall 0.938871473354, not_class_F1 0.949036176393
# 		MacroF1Mesure 0.935778626133
# threshold -0.837
# 	class_prec 0.908300395257, class_recall 0.937959183673, class_F1 0.922891566265
# 	not_class_prec 0.959445037353, not_class_recall 0.939393939394, not_class_F1 0.949313621964
# 		MacroF1Mesure 0.936102594115
# threshold -0.836
# 	class_prec 0.908300395257, class_recall 0.937959183673, class_F1 0.922891566265
# 	not_class_prec 0.959445037353, not_class_recall 0.939393939394, not_class_F1 0.949313621964
# 		MacroF1Mesure 0.936102594115
# threshold -0.835
# 	class_prec 0.90973871734, class_recall 0.937959183673, class_F1 0.923633440514
# 	not_class_prec 0.959488272921, not_class_recall 0.940438871473, not_class_F1 0.949868073879
# 		MacroF1Mesure 0.936750757197
# threshold -0.834
# 	class_prec 0.911181601903, class_recall 0.937959183673, class_F1 0.924376508447
# 	not_class_prec 0.9595314164, not_class_recall 0.941483803553, not_class_F1 0.950421940928
# 		MacroF1Mesure 0.937399224688
# threshold -0.833
# 	class_prec 0.91104050834, class_recall 0.936326530612, class_F1 0.923510466989
# 	not_class_prec 0.958510638298, not_class_recall 0.941483803553, not_class_F1 0.949920927781
# 		MacroF1Mesure 0.936715697385
# threshold -0.832
# 	class_prec 0.91104050834, class_recall 0.936326530612, class_F1 0.923510466989
# 	not_class_prec 0.958510638298, not_class_recall 0.941483803553, not_class_F1 0.949920927781
# 		MacroF1Mesure 0.936715697385
# threshold -0.831
# 	class_prec 0.910969793323, class_recall 0.935510204082, class_F1 0.923076923077
# 	not_class_prec 0.958001063264, not_class_recall 0.941483803553, not_class_F1 0.949670619236
# 		MacroF1Mesure 0.936373771156
# threshold -0.83
# 	class_prec 0.91169451074, class_recall 0.935510204082, class_F1 0.923448831587
# 	not_class_prec 0.958023379384, not_class_recall 0.942006269592, not_class_F1 0.949947312961
# 		MacroF1Mesure 0.936698072274
# threshold -0.829
# 	class_prec 0.91307814992, class_recall 0.934693877551, class_F1 0.923759580476
# 	not_class_prec 0.957559681698, not_class_recall 0.943051201672, not_class_F1 0.950250065807
# 		MacroF1Mesure 0.937004823141
# threshold -0.828
# 	class_prec 0.913008778931, class_recall 0.93387755102, class_F1 0.923325262308
# 	not_class_prec 0.957051961824, not_class_recall 0.943051201672, not_class_F1 0.95
# 		MacroF1Mesure 0.936662631154
# threshold -0.827
# 	class_prec 0.91446842526, class_recall 0.93387755102, class_F1 0.924071082391
# 	not_class_prec 0.957097457627, not_class_recall 0.944096133751, not_class_F1 0.950552340873
# 		MacroF1Mesure 0.937311711632
# threshold -0.826
# 	class_prec 0.914331465172, class_recall 0.932244897959, class_F1 0.923201293452
# 	not_class_prec 0.956084656085, not_class_recall 0.944096133751, not_class_F1 0.950052576236
# 		MacroF1Mesure 0.936626934844
# threshold -0.825
# 	class_prec 0.915797914996, class_recall 0.932244897959, class_F1 0.923948220065
# 	not_class_prec 0.956131078224, not_class_recall 0.945141065831, not_class_F1 0.950604308986
# 		MacroF1Mesure 0.937276264525
# threshold -0.824
# 	class_prec 0.916532905297, class_recall 0.932244897959, class_F1 0.924322136787
# 	not_class_prec 0.956154252509, not_class_recall 0.94566353187, not_class_F1 0.950879957972
# 		MacroF1Mesure 0.937601047379
# threshold -0.823
# 	class_prec 0.917269076305, class_recall 0.932244897959, class_F1 0.924696356275
# 	not_class_prec 0.956177402323, not_class_recall 0.94618599791, not_class_F1 0.951155462185
# 		MacroF1Mesure 0.93792590923
# threshold -0.822
# 	class_prec 0.917202572347, class_recall 0.931428571429, class_F1 0.924260834346
# 	not_class_prec 0.955672823219, not_class_recall 0.94618599791, not_class_F1 0.950905749541
# 		MacroF1Mesure 0.937583291943
# threshold -0.821
# 	class_prec 0.917202572347, class_recall 0.931428571429, class_F1 0.924260834346
# 	not_class_prec 0.955672823219, not_class_recall 0.94618599791, not_class_F1 0.950905749541
# 		MacroF1Mesure 0.937583291943
# threshold -0.82
# 	class_prec 0.917202572347, class_recall 0.931428571429, class_F1 0.924260834346
# 	not_class_prec 0.955672823219, not_class_recall 0.94618599791, not_class_F1 0.950905749541
# 		MacroF1Mesure 0.937583291943
# threshold -0.819
# 	class_prec 0.917135961384, class_recall 0.930612244898, class_F1 0.923824959481
# 	not_class_prec 0.955168776371, not_class_recall 0.94618599791, not_class_F1 0.950656167979
# 		MacroF1Mesure 0.93724056373
# threshold -0.818
# 	class_prec 0.917135961384, class_recall 0.930612244898, class_F1 0.923824959481
# 	not_class_prec 0.955168776371, not_class_recall 0.94618599791, not_class_F1 0.950656167979
# 		MacroF1Mesure 0.93724056373
# threshold -0.817
# 	class_prec 0.917874396135, class_recall 0.930612244898, class_F1 0.924199432509
# 	not_class_prec 0.955192409067, not_class_recall 0.94670846395, not_class_F1 0.950931514038
# 		MacroF1Mesure 0.937565473274
# threshold -0.816
# 	class_prec 0.917874396135, class_recall 0.930612244898, class_F1 0.924199432509
# 	not_class_prec 0.955192409067, not_class_recall 0.94670846395, not_class_F1 0.950931514038
# 		MacroF1Mesure 0.937565473274
# threshold -0.815
# 	class_prec 0.919289749798, class_recall 0.929795918367, class_F1 0.924512987013
# 	not_class_prec 0.954736842105, not_class_recall 0.947753396029, not_class_F1 0.951232302045
# 		MacroF1Mesure 0.937872644529
# threshold -0.814
# 	class_prec 0.919289749798, class_recall 0.929795918367, class_F1 0.924512987013
# 	not_class_prec 0.954736842105, not_class_recall 0.947753396029, not_class_F1 0.951232302045
# 		MacroF1Mesure 0.937872644529
# threshold -0.813
# 	class_prec 0.919224555735, class_recall 0.928979591837, class_F1 0.924076329679
# 	not_class_prec 0.954234613361, not_class_recall 0.947753396029, not_class_F1 0.950982961992
# 		MacroF1Mesure 0.937529645836
# threshold -0.812
# 	class_prec 0.921457489879, class_recall 0.928979591837, class_F1 0.925203252033
# 	not_class_prec 0.954306722689, not_class_recall 0.949320794148, not_class_F1 0.951807228916
# 		MacroF1Mesure 0.938505240474
# threshold -0.811
# 	class_prec 0.922204213938, class_recall 0.928979591837, class_F1 0.925579503863
# 	not_class_prec 0.954330708661, not_class_recall 0.949843260188, not_class_F1 0.952081696779
# 		MacroF1Mesure 0.938830600321
# threshold -0.81
# 	class_prec 0.922826969943, class_recall 0.927346938776, class_F1 0.925081433225
# 	not_class_prec 0.953354297694, not_class_recall 0.950365726228, not_class_F1 0.951857666143
# 		MacroF1Mesure 0.938469549684
# threshold -0.809
# 	class_prec 0.925020374898, class_recall 0.926530612245, class_F1 0.925774877651
# 	not_class_prec 0.952928870293, not_class_recall 0.951933124347, not_class_F1 0.952430737062
# 		MacroF1Mesure 0.939102807357
# threshold -0.808
# 	class_prec 0.925020374898, class_recall 0.926530612245, class_F1 0.925774877651
# 	not_class_prec 0.952928870293, not_class_recall 0.951933124347, not_class_F1 0.952430737062
# 		MacroF1Mesure 0.939102807357
# threshold -0.807
# 	class_prec 0.926530612245, class_recall 0.926530612245, class_F1 0.926530612245
# 	not_class_prec 0.952978056426, not_class_recall 0.952978056426, not_class_F1 0.952978056426
# 		MacroF1Mesure 0.939754334336
# threshold -0.806
# 	class_prec 0.927228127555, class_recall 0.925714285714, class_F1 0.926470588235
# 	not_class_prec 0.952505219207, not_class_recall 0.953500522466, not_class_F1 0.953002610966
# 		MacroF1Mesure 0.939736599601
# threshold -0.805
# 	class_prec 0.92798690671, class_recall 0.925714285714, class_F1 0.926849203106
# 	not_class_prec 0.952529994784, not_class_recall 0.954022988506, not_class_F1 0.953275907074
# 		MacroF1Mesure 0.94006255509
# threshold -0.804
# 	class_prec 0.92868852459, class_recall 0.924897959184, class_F1 0.926789366053
# 	not_class_prec 0.952058363731, not_class_recall 0.954545454545, not_class_F1 0.953300286981
# 		MacroF1Mesure 0.940044826517
# threshold -0.803
# 	class_prec 0.928571428571, class_recall 0.923265306122, class_F1 0.925910765452
# 	not_class_prec 0.951067152525, not_class_recall 0.954545454545, not_class_F1 0.952803129074
# 		MacroF1Mesure 0.939356947263
# threshold -0.802
# 	class_prec 0.929276315789, class_recall 0.922448979592, class_F1 0.92585006145
# 	not_class_prec 0.950598023921, not_class_recall 0.955067920585, not_class_F1 0.952827729997
# 		MacroF1Mesure 0.939338895724
# threshold -0.801
# 	class_prec 0.929276315789, class_recall 0.922448979592, class_F1 0.92585006145
# 	not_class_prec 0.950598023921, not_class_recall 0.955067920585, not_class_F1 0.952827729997
# 		MacroF1Mesure 0.939338895724
# threshold -0.8
# 	class_prec 0.929159802306, class_recall 0.920816326531, class_F1 0.924969249692
# 	not_class_prec 0.94961038961, not_class_recall 0.955067920585, not_class_F1 0.952331336285
# 		MacroF1Mesure 0.938650292989
# threshold -0.799
# 	class_prec 0.929867986799, class_recall 0.92, class_F1 0.924907673369
# 	not_class_prec 0.949143746757, not_class_recall 0.955590386625, not_class_F1 0.952356157251
# 		MacroF1Mesure 0.93863191531
# threshold -0.798
# 	class_prec 0.930578512397, class_recall 0.919183673469, class_F1 0.924845995893
# 	not_class_prec 0.94867807154, not_class_recall 0.956112852665, not_class_F1 0.952380952381
# 		MacroF1Mesure 0.938613474137
# threshold -0.797
# 	class_prec 0.930578512397, class_recall 0.919183673469, class_F1 0.924845995893
# 	not_class_prec 0.94867807154, not_class_recall 0.956112852665, not_class_F1 0.952380952381
# 		MacroF1Mesure 0.938613474137
# threshold -0.796
# 	class_prec 0.932119205298, class_recall 0.919183673469, class_F1 0.925606247431
# 	not_class_prec 0.948731227343, not_class_recall 0.957157784744, not_class_F1 0.952925877763
# 		MacroF1Mesure 0.939266062597
# threshold -0.795
# 	class_prec 0.932119205298, class_recall 0.919183673469, class_F1 0.925606247431
# 	not_class_prec 0.948731227343, not_class_recall 0.957157784744, not_class_F1 0.952925877763
# 		MacroF1Mesure 0.939266062597
# threshold -0.794
# 	class_prec 0.932119205298, class_recall 0.919183673469, class_F1 0.925606247431
# 	not_class_prec 0.948731227343, not_class_recall 0.957157784744, not_class_F1 0.952925877763
# 		MacroF1Mesure 0.939266062597
# threshold -0.793
# 	class_prec 0.932119205298, class_recall 0.919183673469, class_F1 0.925606247431
# 	not_class_prec 0.948731227343, not_class_recall 0.957157784744, not_class_F1 0.952925877763
# 		MacroF1Mesure 0.939266062597
# threshold -0.792
# 	class_prec 0.932119205298, class_recall 0.919183673469, class_F1 0.925606247431
# 	not_class_prec 0.948731227343, not_class_recall 0.957157784744, not_class_F1 0.952925877763
# 		MacroF1Mesure 0.939266062597
# threshold -0.791
# 	class_prec 0.932119205298, class_recall 0.919183673469, class_F1 0.925606247431
# 	not_class_prec 0.948731227343, not_class_recall 0.957157784744, not_class_F1 0.952925877763
# 		MacroF1Mesure 0.939266062597
# threshold -0.79
# 	class_prec 0.932119205298, class_recall 0.919183673469, class_F1 0.925606247431
# 	not_class_prec 0.948731227343, not_class_recall 0.957157784744, not_class_F1 0.952925877763
# 		MacroF1Mesure 0.939266062597
# threshold -0.789
# 	class_prec 0.932891466446, class_recall 0.919183673469, class_F1 0.925986842105
# 	not_class_prec 0.948757763975, not_class_recall 0.957680250784, not_class_F1 0.953198127925
# 		MacroF1Mesure 0.939592485015
# threshold -0.788
# 	class_prec 0.932891466446, class_recall 0.919183673469, class_F1 0.925986842105
# 	not_class_prec 0.948757763975, not_class_recall 0.957680250784, not_class_F1 0.953198127925
# 		MacroF1Mesure 0.939592485015
# threshold -0.787
# 	class_prec 0.934330839568, class_recall 0.917551020408, class_F1 0.92586490939
# 	not_class_prec 0.947830578512, not_class_recall 0.958725182863, not_class_F1 0.953246753247
# 		MacroF1Mesure 0.939555831319
# threshold -0.786
# 	class_prec 0.934330839568, class_recall 0.917551020408, class_F1 0.92586490939
# 	not_class_prec 0.947830578512, not_class_recall 0.958725182863, not_class_F1 0.953246753247
# 		MacroF1Mesure 0.939555831319
# threshold -0.785
# 	class_prec 0.935833333333, class_recall 0.916734693878, class_F1 0.92618556701
# 	not_class_prec 0.947395564724, not_class_recall 0.959770114943, not_class_F1 0.953542694005
# 		MacroF1Mesure 0.939864130507
# threshold -0.784
# 	class_prec 0.936613844871, class_recall 0.916734693878, class_F1 0.926567656766
# 	not_class_prec 0.947422680412, not_class_recall 0.960292580982, not_class_F1 0.953814218993
# 		MacroF1Mesure 0.940190937879
# threshold -0.783
# 	class_prec 0.937395659432, class_recall 0.916734693878, class_F1 0.926950061907
# 	not_class_prec 0.947449768161, not_class_recall 0.960815047022, not_class_F1 0.954085603113
# 		MacroF1Mesure 0.94051783251
# threshold -0.782
# 	class_prec 0.937395659432, class_recall 0.916734693878, class_F1 0.926950061907
# 	not_class_prec 0.947449768161, not_class_recall 0.960815047022, not_class_F1 0.954085603113
# 		MacroF1Mesure 0.94051783251
# threshold -0.781
# 	class_prec 0.937343358396, class_recall 0.915918367347, class_F1 0.926507018993
# 	not_class_prec 0.946961894954, not_class_recall 0.960815047022, not_class_F1 0.953838174274
# 		MacroF1Mesure 0.940172596633
# threshold -0.78
# 	class_prec 0.938912133891, class_recall 0.915918367347, class_F1 0.927272727273
# 	not_class_prec 0.947016460905, not_class_recall 0.961859979101, not_class_F1 0.954380508035
# 		MacroF1Mesure 0.940826617654
# threshold -0.779
# 	class_prec 0.938912133891, class_recall 0.915918367347, class_F1 0.927272727273
# 	not_class_prec 0.947016460905, not_class_recall 0.961859979101, not_class_F1 0.954380508035
# 		MacroF1Mesure 0.940826617654
# threshold -0.778
# 	class_prec 0.939698492462, class_recall 0.915918367347, class_F1 0.927656056222
# 	not_class_prec 0.947043701799, not_class_recall 0.962382445141, not_class_F1 0.95465146411
# 		MacroF1Mesure 0.941153760166
# threshold -0.777
# 	class_prec 0.941275167785, class_recall 0.915918367347, class_F1 0.928423665701
# 	not_class_prec 0.94709809964, not_class_recall 0.96342737722, not_class_F1 0.955192955193
# 		MacroF1Mesure 0.941808310447
# threshold -0.776
# 	class_prec 0.941275167785, class_recall 0.915918367347, class_F1 0.928423665701
# 	not_class_prec 0.94709809964, not_class_recall 0.96342737722, not_class_F1 0.955192955193
# 		MacroF1Mesure 0.941808310447
# threshold -0.775
# 	class_prec 0.942065491184, class_recall 0.915918367347, class_F1 0.92880794702
# 	not_class_prec 0.947125256674, not_class_recall 0.96394984326, not_class_F1 0.955463490419
# 		MacroF1Mesure 0.94213571872
# threshold -0.774
# 	class_prec 0.942016806723, class_recall 0.915102040816, class_F1 0.928364389234
# 	not_class_prec 0.946639302206, not_class_recall 0.96394984326, not_class_F1 0.955216153249
# 		MacroF1Mesure 0.941790271241
# threshold -0.773
# 	class_prec 0.942016806723, class_recall 0.915102040816, class_F1 0.928364389234
# 	not_class_prec 0.946639302206, not_class_recall 0.96394984326, not_class_F1 0.955216153249
# 		MacroF1Mesure 0.941790271241
# threshold -0.772
# 	class_prec 0.94196804037, class_recall 0.914285714286, class_F1 0.92792046396
# 	not_class_prec 0.946153846154, not_class_recall 0.96394984326, not_class_F1 0.954968944099
# 		MacroF1Mesure 0.94144470403
# threshold -0.771
# 	class_prec 0.94196804037, class_recall 0.914285714286, class_F1 0.92792046396
# 	not_class_prec 0.946153846154, not_class_recall 0.96394984326, not_class_F1 0.954968944099
# 		MacroF1Mesure 0.94144470403
# threshold -0.77
# 	class_prec 0.94196804037, class_recall 0.914285714286, class_F1 0.92792046396
# 	not_class_prec 0.946153846154, not_class_recall 0.96394984326, not_class_F1 0.954968944099
# 		MacroF1Mesure 0.94144470403
# threshold -0.769
# 	class_prec 0.942760942761, class_recall 0.914285714286, class_F1 0.928305014505
# 	not_class_prec 0.946181445413, not_class_recall 0.9644723093, not_class_F1 0.955239327296
# 		MacroF1Mesure 0.941772170901
# threshold -0.768
# 	class_prec 0.942712721146, class_recall 0.913469387755, class_F1 0.927860696517
# 	not_class_prec 0.945696721311, not_class_recall 0.9644723093, not_class_F1 0.954992240041
# 		MacroF1Mesure 0.941426468279
# threshold -0.767
# 	class_prec 0.944303797468, class_recall 0.913469387755, class_F1 0.928630705394
# 	not_class_prec 0.945752302968, not_class_recall 0.965517241379, not_class_F1 0.955532574974
# 		MacroF1Mesure 0.942081640184
# threshold -0.766
# 	class_prec 0.944256756757, class_recall 0.912653061224, class_F1 0.928185969282
# 	not_class_prec 0.945268542199, not_class_recall 0.965517241379, not_class_F1 0.955285603515
# 		MacroF1Mesure 0.941735786398
# threshold -0.765
# 	class_prec 0.944162436548, class_recall 0.911020408163, class_F1 0.92729538845
# 	not_class_prec 0.944302503832, not_class_recall 0.965517241379, not_class_F1 0.9547920434
# 		MacroF1Mesure 0.941043715925
# threshold -0.764
# 	class_prec 0.944162436548, class_recall 0.911020408163, class_F1 0.92729538845
# 	not_class_prec 0.944302503832, not_class_recall 0.965517241379, not_class_F1 0.9547920434
# 		MacroF1Mesure 0.941043715925
# threshold -0.763
# 	class_prec 0.944115156647, class_recall 0.910204081633, class_F1 0.92684954281
# 	not_class_prec 0.943820224719, not_class_recall 0.965517241379, not_class_F1 0.954545454545
# 		MacroF1Mesure 0.940697498678
# threshold -0.762
# 	class_prec 0.944115156647, class_recall 0.910204081633, class_F1 0.92684954281
# 	not_class_prec 0.943820224719, not_class_recall 0.965517241379, not_class_F1 0.954545454545
# 		MacroF1Mesure 0.940697498678
# threshold -0.761
# 	class_prec 0.944020356234, class_recall 0.908571428571, class_F1 0.925956738769
# 	not_class_prec 0.942857142857, not_class_recall 0.965517241379, not_class_F1 0.954052658751
# 		MacroF1Mesure 0.94000469876
# threshold -0.76
# 	class_prec 0.944020356234, class_recall 0.908571428571, class_F1 0.925956738769
# 	not_class_prec 0.942857142857, not_class_recall 0.965517241379, not_class_F1 0.954052658751
# 		MacroF1Mesure 0.94000469876
# threshold -0.759
# 	class_prec 0.943972835314, class_recall 0.907755102041, class_F1 0.925509779442
# 	not_class_prec 0.942376338603, not_class_recall 0.965517241379, not_class_F1 0.953806451613
# 		MacroF1Mesure 0.939658115528
# threshold -0.758
# 	class_prec 0.944727891156, class_recall 0.90693877551, class_F1 0.925447730112
# 	not_class_prec 0.941925624045, not_class_recall 0.966039707419, not_class_F1 0.953830281145
# 		MacroF1Mesure 0.939639005629
# threshold -0.757
# 	class_prec 0.945439045183, class_recall 0.905306122449, class_F1 0.924937447873
# 	not_class_prec 0.940996948118, not_class_recall 0.966562173459, not_class_F1 0.953608247423
# 		MacroF1Mesure 0.939272847648
# threshold -0.756
# 	class_prec 0.946199829206, class_recall 0.904489795918, class_F1 0.924874791319
# 	not_class_prec 0.940548780488, not_class_recall 0.967084639498, not_class_F1 0.953632148377
# 		MacroF1Mesure 0.939253469848
# threshold -0.755
# 	class_prec 0.946199829206, class_recall 0.904489795918, class_F1 0.924874791319
# 	not_class_prec 0.940548780488, not_class_recall 0.967084639498, not_class_F1 0.953632148377
# 		MacroF1Mesure 0.939253469848
# threshold -0.754
# 	class_prec 0.946153846154, class_recall 0.903673469388, class_F1 0.924425887265
# 	not_class_prec 0.940071102082, not_class_recall 0.967084639498, not_class_F1 0.953386556786
# 		MacroF1Mesure 0.938906222026
# threshold -0.753
# 	class_prec 0.946107784431, class_recall 0.902857142857, class_F1 0.923976608187
# 	not_class_prec 0.939593908629, not_class_recall 0.967084639498, not_class_F1 0.953141091658
# 		MacroF1Mesure 0.938558849923
# threshold -0.752
# 	class_prec 0.946107784431, class_recall 0.902857142857, class_F1 0.923976608187
# 	not_class_prec 0.939593908629, not_class_recall 0.967084639498, not_class_F1 0.953141091658
# 		MacroF1Mesure 0.938558849923
# threshold -0.751
# 	class_prec 0.946917808219, class_recall 0.902857142857, class_F1 0.924362724613
# 	not_class_prec 0.939624556063, not_class_recall 0.967607105538, not_class_F1 0.953410553411
# 		MacroF1Mesure 0.938886639012
# threshold -0.75
# 	class_prec 0.946826758148, class_recall 0.901224489796, class_F1 0.923462986198
# 	not_class_prec 0.938672072985, not_class_recall 0.967607105538, not_class_F1 0.952919989709
# 		MacroF1Mesure 0.938191487954
# threshold -0.749
# 	class_prec 0.946826758148, class_recall 0.901224489796, class_F1 0.923462986198
# 	not_class_prec 0.938672072985, not_class_recall 0.967607105538, not_class_F1 0.952919989709
# 		MacroF1Mesure 0.938191487954
# threshold -0.748
# 	class_prec 0.94678111588, class_recall 0.900408163265, class_F1 0.923012552301
# 	not_class_prec 0.938196555218, not_class_recall 0.967607105538, not_class_F1 0.952674897119
# 		MacroF1Mesure 0.93784372471
# threshold -0.747
# 	class_prec 0.948364888124, class_recall 0.899591836735, class_F1 0.923334729786
# 	not_class_prec 0.937784522003, not_class_recall 0.968652037618, not_class_F1 0.952968388589
# 		MacroF1Mesure 0.938151559188
# threshold -0.746
# 	class_prec 0.948320413437, class_recall 0.898775510204, class_F1 0.922883487008
# 	not_class_prec 0.93731041456, not_class_recall 0.968652037618, not_class_F1 0.952723535457
# 		MacroF1Mesure 0.937803511232
# threshold -0.745
# 	class_prec 0.948320413437, class_recall 0.898775510204, class_F1 0.922883487008
# 	not_class_prec 0.93731041456, not_class_recall 0.968652037618, not_class_F1 0.952723535457
# 		MacroF1Mesure 0.937803511232
# threshold -0.744
# 	class_prec 0.948320413437, class_recall 0.898775510204, class_F1 0.922883487008
# 	not_class_prec 0.93731041456, not_class_recall 0.968652037618, not_class_F1 0.952723535457
# 		MacroF1Mesure 0.937803511232
# threshold -0.743
# 	class_prec 0.948320413437, class_recall 0.898775510204, class_F1 0.922883487008
# 	not_class_prec 0.93731041456, not_class_recall 0.968652037618, not_class_F1 0.952723535457
# 		MacroF1Mesure 0.937803511232
# threshold -0.742
# 	class_prec 0.949050086356, class_recall 0.897142857143, class_F1 0.922366764582
# 	not_class_prec 0.936395759717, not_class_recall 0.969174503657, not_class_F1 0.952503209243
# 		MacroF1Mesure 0.937434986913
# threshold -0.741
# 	class_prec 0.949826989619, class_recall 0.896326530612, class_F1 0.922301553969
# 	not_class_prec 0.935955622794, not_class_recall 0.969696969697, not_class_F1 0.952527585322
# 		MacroF1Mesure 0.937414569645
# threshold -0.74
# 	class_prec 0.950649350649, class_recall 0.896326530612, class_F1 0.92268907563
# 	not_class_prec 0.935987903226, not_class_recall 0.970219435737, not_class_F1 0.952796305798
# 		MacroF1Mesure 0.937742690714
# threshold -0.739
# 	class_prec 0.951473136915, class_recall 0.896326530612, class_F1 0.923076923077
# 	not_class_prec 0.936020151134, not_class_recall 0.970741901776, not_class_F1 0.953064888433
# 		MacroF1Mesure 0.938070905755
# threshold -0.738
# 	class_prec 0.951388888889, class_recall 0.894693877551, class_F1 0.922170803534
# 	not_class_prec 0.935078007046, not_class_recall 0.970741901776, not_class_F1 0.952576262497
# 		MacroF1Mesure 0.937373533015
# threshold -0.737
# 	class_prec 0.951388888889, class_recall 0.894693877551, class_F1 0.922170803534
# 	not_class_prec 0.935078007046, not_class_recall 0.970741901776, not_class_F1 0.952576262497
# 		MacroF1Mesure 0.937373533015
# threshold -0.736
# 	class_prec 0.951388888889, class_recall 0.894693877551, class_F1 0.922170803534
# 	not_class_prec 0.935078007046, not_class_recall 0.970741901776, not_class_F1 0.952576262497
# 		MacroF1Mesure 0.937373533015
# threshold -0.735
# 	class_prec 0.951346655083, class_recall 0.89387755102, class_F1 0.921717171717
# 	not_class_prec 0.934607645875, not_class_recall 0.970741901776, not_class_F1 0.952332137365
# 		MacroF1Mesure 0.937024654541
# threshold -0.734
# 	class_prec 0.951346655083, class_recall 0.89387755102, class_F1 0.921717171717
# 	not_class_prec 0.934607645875, not_class_recall 0.970741901776, not_class_F1 0.952332137365
# 		MacroF1Mesure 0.937024654541
# threshold -0.733
# 	class_prec 0.952132288947, class_recall 0.89306122449, class_F1 0.921651221567
# 	not_class_prec 0.934170854271, not_class_recall 0.971264367816, not_class_F1 0.952356557377
# 		MacroF1Mesure 0.937003889472
# threshold -0.732
# 	class_prec 0.952048823017, class_recall 0.891428571429, class_F1 0.920741989882
# 	not_class_prec 0.933232931727, not_class_recall 0.971264367816, not_class_F1 0.951868919611
# 		MacroF1Mesure 0.936305454746
# threshold -0.731
# 	class_prec 0.952048823017, class_recall 0.891428571429, class_F1 0.920741989882
# 	not_class_prec 0.933232931727, not_class_recall 0.971264367816, not_class_F1 0.951868919611
# 		MacroF1Mesure 0.936305454746
# threshold -0.73
# 	class_prec 0.952048823017, class_recall 0.891428571429, class_F1 0.920741989882
# 	not_class_prec 0.933232931727, not_class_recall 0.971264367816, not_class_F1 0.951868919611
# 		MacroF1Mesure 0.936305454746
# threshold -0.729
# 	class_prec 0.953671328671, class_recall 0.890612244898, class_F1 0.921063739975
# 	not_class_prec 0.932832080201, not_class_recall 0.972309299896, not_class_F1 0.952161678179
# 		MacroF1Mesure 0.936612709077
# threshold -0.728
# 	class_prec 0.953671328671, class_recall 0.890612244898, class_F1 0.921063739975
# 	not_class_prec 0.932832080201, not_class_recall 0.972309299896, not_class_F1 0.952161678179
# 		MacroF1Mesure 0.936612709077
# threshold -0.727
# 	class_prec 0.954465849387, class_recall 0.889795918367, class_F1 0.92099704267
# 	not_class_prec 0.932398597897, not_class_recall 0.972831765935, not_class_F1 0.952186141652
# 		MacroF1Mesure 0.936591592161
# threshold -0.726
# 	class_prec 0.955145118734, class_recall 0.886530612245, class_F1 0.919559695174
# 	not_class_prec 0.930569430569, not_class_recall 0.973354231975, not_class_F1 0.951481103166
# 		MacroF1Mesure 0.93552039917
# threshold -0.725
# 	class_prec 0.955066079295, class_recall 0.884897959184, class_F1 0.918644067797
# 	not_class_prec 0.929640718563, not_class_recall 0.973354231975, not_class_F1 0.950995405819
# 		MacroF1Mesure 0.934819736808
# threshold -0.724
# 	class_prec 0.955869373345, class_recall 0.884081632653, class_F1 0.918575063613
# 	not_class_prec 0.929212362911, not_class_recall 0.973876698015, not_class_F1 0.951020408163
# 		MacroF1Mesure 0.934797735888
# threshold -0.723
# 	class_prec 0.955869373345, class_recall 0.884081632653, class_F1 0.918575063613
# 	not_class_prec 0.929212362911, not_class_recall 0.973876698015, not_class_F1 0.951020408163
# 		MacroF1Mesure 0.934797735888
# threshold -0.722
# 	class_prec 0.955830388693, class_recall 0.883265306122, class_F1 0.91811624947
# 	not_class_prec 0.92874937718, not_class_recall 0.973876698015, not_class_F1 0.95077786279
# 		MacroF1Mesure 0.93444705613
# threshold -0.721
# 	class_prec 0.955830388693, class_recall 0.883265306122, class_F1 0.91811624947
# 	not_class_prec 0.92874937718, not_class_recall 0.973876698015, not_class_F1 0.95077786279
# 		MacroF1Mesure 0.93444705613
# threshold -0.72
# 	class_prec 0.957409050577, class_recall 0.880816326531, class_F1 0.917517006803
# 	not_class_prec 0.927435387674, not_class_recall 0.974921630094, not_class_F1 0.950585838003
# 		MacroF1Mesure 0.934051422403
# threshold -0.719
# 	class_prec 0.958259325044, class_recall 0.880816326531, class_F1 0.917907273501
# 	not_class_prec 0.927471435668, not_class_recall 0.975444096134, not_class_F1 0.9508530685
# 		MacroF1Mesure 0.934380171
# threshold -0.718
# 	class_prec 0.959111111111, class_recall 0.880816326531, class_F1 0.91829787234
# 	not_class_prec 0.927507447865, not_class_recall 0.975966562173, not_class_F1 0.951120162933
# 		MacroF1Mesure 0.934709017637
# threshold -0.717
# 	class_prec 0.959111111111, class_recall 0.880816326531, class_F1 0.91829787234
# 	not_class_prec 0.927507447865, not_class_recall 0.975966562173, not_class_F1 0.951120162933
# 		MacroF1Mesure 0.934709017637
# threshold -0.716
# 	class_prec 0.959111111111, class_recall 0.880816326531, class_F1 0.91829787234
# 	not_class_prec 0.927507447865, not_class_recall 0.975966562173, not_class_F1 0.951120162933
# 		MacroF1Mesure 0.934709017637
# threshold -0.715
# 	class_prec 0.959111111111, class_recall 0.880816326531, class_F1 0.91829787234
# 	not_class_prec 0.927507447865, not_class_recall 0.975966562173, not_class_F1 0.951120162933
# 		MacroF1Mesure 0.934709017637
# threshold -0.714
# 	class_prec 0.959964412811, class_recall 0.880816326531, class_F1 0.918688803746
# 	not_class_prec 0.927543424318, not_class_recall 0.976489028213, not_class_F1 0.951387121405
# 		MacroF1Mesure 0.935037962576
# threshold -0.713
# 	class_prec 0.959964412811, class_recall 0.880816326531, class_F1 0.918688803746
# 	not_class_prec 0.927543424318, not_class_recall 0.976489028213, not_class_F1 0.951387121405
# 		MacroF1Mesure 0.935037962576
# threshold -0.712
# 	class_prec 0.959964412811, class_recall 0.880816326531, class_F1 0.918688803746
# 	not_class_prec 0.927543424318, not_class_recall 0.976489028213, not_class_F1 0.951387121405
# 		MacroF1Mesure 0.935037962576
# threshold -0.711
# 	class_prec 0.960784313725, class_recall 0.88, class_F1 0.918619514274
# 	not_class_prec 0.927119484383, not_class_recall 0.977011494253, not_class_F1 0.95141185449
# 		MacroF1Mesure 0.935015684382
# threshold -0.71
# 	class_prec 0.960749330955, class_recall 0.879183673469, class_F1 0.918158567775
# 	not_class_prec 0.926660059465, not_class_recall 0.977011494253, not_class_F1 0.951169888098
# 		MacroF1Mesure 0.934664227936
# threshold -0.709
# 	class_prec 0.960749330955, class_recall 0.879183673469, class_F1 0.918158567775
# 	not_class_prec 0.926660059465, not_class_recall 0.977011494253, not_class_F1 0.951169888098
# 		MacroF1Mesure 0.934664227936
# threshold -0.708
# 	class_prec 0.960749330955, class_recall 0.879183673469, class_F1 0.918158567775
# 	not_class_prec 0.926660059465, not_class_recall 0.977011494253, not_class_F1 0.951169888098
# 		MacroF1Mesure 0.934664227936
# threshold -0.707
# 	class_prec 0.960749330955, class_recall 0.879183673469, class_F1 0.918158567775
# 	not_class_prec 0.926660059465, not_class_recall 0.977011494253, not_class_F1 0.951169888098
# 		MacroF1Mesure 0.934664227936
# threshold -0.706
# 	class_prec 0.962432915921, class_recall 0.878367346939, class_F1 0.918480580452
# 	not_class_prec 0.926274121722, not_class_recall 0.978056426332, not_class_F1 0.951461245235
# 		MacroF1Mesure 0.934970912844
# threshold -0.705
# 	class_prec 0.962399283796, class_recall 0.877551020408, class_F1 0.918018787361
# 	not_class_prec 0.925816023739, not_class_recall 0.978056426332, not_class_F1 0.951219512195
# 		MacroF1Mesure 0.934619149778
# threshold -0.704
# 	class_prec 0.962399283796, class_recall 0.877551020408, class_F1 0.918018787361
# 	not_class_prec 0.925816023739, not_class_recall 0.978056426332, not_class_F1 0.951219512195
# 		MacroF1Mesure 0.934619149778
# threshold -0.703
# 	class_prec 0.962365591398, class_recall 0.876734693878, class_F1 0.917556599744
# 	not_class_prec 0.925358378646, not_class_recall 0.978056426332, not_class_F1 0.950977901956
# 		MacroF1Mesure 0.93426725085
# threshold -0.702
# 	class_prec 0.963228699552, class_recall 0.876734693878, class_F1 0.917948717949
# 	not_class_prec 0.925395256917, not_class_recall 0.978578892372, not_class_F1 0.95124428644
# 		MacroF1Mesure 0.934596502194
# threshold -0.701
# 	class_prec 0.963228699552, class_recall 0.876734693878, class_F1 0.917948717949
# 	not_class_prec 0.925395256917, not_class_recall 0.978578892372, not_class_F1 0.95124428644
# 		MacroF1Mesure 0.934596502194

# %%
TEST_DATA_FILE  = 'kaggle_test_data_tab.csv.gz'

threshold = -0.775
    
test_docs = load_csv(TEST_DATA_FILE)

with open(str(threshold) + 'my_submission.csv', 'wb') as fout:
    writer = csv.writer(fout)
    writer.writerow(['Id','Prediction'])
    for item in classifier.predict_all(test_docs):
        prediction =  1 if item[3] > threshold else 0
        writer.writerow([item[0], prediction])
# Out:
# 18:02:39 INFO:Complete items 00000
# 18:02:39 INFO:Complete items 00000
# 18:02:57 INFO:Complete items 00500
# 18:02:57 INFO:Complete items 00500
# 18:03:14 INFO:Complete items 01000
# 18:03:14 INFO:Complete items 01000
# 18:03:16 INFO:Complete items 01075
